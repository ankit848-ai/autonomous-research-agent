# %% [markdown]
# # 🚀 ResearchLab-AI — Demo Pipeline Notebook
#
# This notebook demonstrates the full autonomous research workflow:
# 1. **Researcher Agent** – Literature generation
# 2. **Designer Agent** – Experiment plan
# 3. **Coder + Executor Agent** – ML code generation & execution
# 4. **Analyst Agent** – Metrics & accuracy plot
# 5. **Writer Agent** – PDF + PPTX generation
#
# ---

# %%
from agents.orchestrator import Orchestrator
import os
from IPython.display import Image, display

print("Initializing ResearchLab-AI pipeline...")
orch = Orchestrator()

topic = "sentiment analysis experiment"
print(f"\nRunning pipeline for topic: {topic}\n")

results = orch.run(topic, mode="demo")
results

# %% [markdown]
# ---
# ## ✔ Artifacts Generated
# The pipeline produced the following outputs:
# - Research Paper (**paper.pdf**)
# - Slide Deck (**slides.pptx**)
# - Accuracy Plot (**accuracy.png**)
# - Metrics File (**metrics.json**)
# - Execution Logs (**run_logs.txt**)
#
# Below is the automatically generated accuracy plot:

# %%
accuracy_path = results.get("plot_path", None)
if accuracy_path and os.path.exists(accuracy_path):
    display(Image(filename=accuracy_path))
else:
    print("Accuracy plot not found.")

# %% [markdown]
# ---
# ## 🎉 Pipeline Complete
#
# All outputs have been saved inside the `artifacts/<session_id>/` folder.
#
# You can now open the generated PDF and PPTX files to view the final research paper and presentation.
#
# ---
